# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /opt/anaconda/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda/lib/python3.13/site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
def addition(a, b):
    return a + b

def substract(a, b):
    return a - b

def multiplication(a, b):
    return a * b

def division(a, b):
    try:
        return a/b
    except ZeroDivisionError:
        print("Error: Cannot divide by zero")
        return None

def power(a, b):
    i = 0
    power_a = 1
    for i in range(b):
        power_a = power_a * a
    return power_a
    
def my_sqrt(S, tol=1e-10):
    x = S / 2  # initial guess (anything positive works)
    while True:
        x_new = (x + S / x) / 2
        if abs(x_new - x) < tol:
            return x_new
        x = x_new
def is_even(a):
    return (a // 2) * 2 == a

def sum_to_n(n):
    return (n*(n+1))//2

def eq_gr2(a, b, c):
    x1, x2 = 0, 0
    discriminant = b**2 - 4*a*c
    if discriminant < 0:
        print("There are no real solutions...")
        return None
    elif discriminant == 0:
        x1 = x2 = -b/(2*a)
        return x1, x2
    else:
        x1 = (-b - my_sqrt(discriminant))/(2*a)
        x2 = (-b + my_sqrt(discriminant))/(2*a)
    return x1, x2

# %%
x1, x2 = eq_gr2(5, 5, -6)
print(x1)
print(x2)
# Out:
# -1.7041594578792296
# 0.7041594578792296
